# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7e785003980a9755a14b564494253538&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.shape
# Out:
# (20, 7)

# %%
temp_df.head()
# Out:
#         id                     title  \
# 0  1007757                   Swapped
# 1      278  The Shawshank Redemption
# 2      238             The Godfather
# 3   687163         Project Hail Mary
# 4      240     The Godfather Part II
#
#                                             overview release_date  popularity  \
# 0  A small woodland creature and a majestic bird,...   2026-05-01    314.3613
# 1  Imprisoned in the 1940s for the double murder ...   1994-09-23     73.6464
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     49.9302
# 3  Science teacher Ryland Grace wakes up on a spa...   2026-03-15    371.0794
# 4  In the continuing saga of the Corleone crime f...   1974-12-20     28.6549
#
#    vote_average  vote_count
# 0         8.973        1406
# 1         8.721       30409
# 2         8.687       22947
# 3         8.634        4155
# 4         8.571       13910

# %%
df = pd.DataFrame()

# %%
for i in range(1,544):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7e785003980a9755a14b564494253538&language=en-US&page=1')
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#             id                           title  \
# 0      1007757                         Swapped
# 1          278        The Shawshank Redemption
# 2          238                   The Godfather
# 3       687163               Project Hail Mary
# 4          240           The Godfather Part II
# ...        ...                             ...
# 10855      680                    Pulp Fiction
# 10856   372058                      Your Name.
# 10857   157336                    Interstellar
# 10858      429  The Good, the Bad and the Ugly
# 10859       13                    Forrest Gump
#
#                                                 overview release_date  \
# 0      A small woodland creature and a majestic bird,...   2026-05-01
# 1      Imprisoned in the 1940s for the double murder ...   1994-09-23
# 2      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3      Science teacher Ryland Grace wakes up on a spa...   2026-03-15
# ...

# %%
df.shape
# Out:
# (10860, 7)

# %%
df.to_csv('movies.csv')
